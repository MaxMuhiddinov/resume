# %%
import fastai
import torch
from fastai.vision.all import *
from ipywidgets import widgets

# %%
#!git clone https://github.com/EscVM/OIDv4_ToolKit
#!cd OIDv4_ToolKit && pip install -r requirements.txt
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 38.02 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
#!cd OIDv4_ToolKit && python main.py -h

# %%
# !cd OIDv4_ToolKit && python3 main.py downloader --Dataset /content --classes Car Airplane Boat --type_csv test --limit 200
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Car.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 49 MB, 40161 KB/s, 1 seconds passed
# [DOWNLOAD] | File test-annotations-bbox.csv downloaded into OID/csv_folder/test-annotations-bbox.csv.
#
# Car
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 14663 online images for test.
#     [INFO] | Limiting to 200 images.
#     [INFO] | Download of 200 images in test.
# 100% 200/200 [01:16<00:00,  2.61it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Car of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Airplane.
#
# Airplane
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 2434 online images for test.
#     [INFO] | Limiting to 200 images.
#     [INFO] | Download of 200 images in test.
# 100% 200/200 [01:16<00:00,  2.61it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Airplane of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Boat.
#
# Boat
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 1638 online images for test.
#     [INFO] | Limiting to 200 images.
#     [INFO] | Download of 200 images in test.
# 100% 200/200 [01:18<00:00,  2.55it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Boat of test.
#     [INFO] | Labels creation completed.

# %%
path = Path('test')
fls = get_image_files(path)
failed = verify_images(path)
transports = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(224)
)
dls = transports.dataloaders(path)

dls.train.show_batch(max_n=32, nrows=4)

learn = cnn_learner(dls, resnet34, metrics=accuracy)
learn.fine_tune(4)
# Out:
# zip argument #1 must support iteration
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.157036</td>
#       <td>0.161377</td>
#       <td>0.941667</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.229523</td>
#       <td>0.135646</td>
#       <td>0.966667</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.144721</td>
#       <td>0.227523</td>
#       <td>0.966667</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.099217</td>
#       <td>0.221404</td>
#       <td>0.958333</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.076226</td>
#       <td>0.212521</td>
#       <td>0.958333</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(5, nrows=1)

# %%
upload = widgets.FileUpload()
upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(upload.data[-1])
pred, pred_id, probs = learn.predict(img)
print(f"Bashorat:{pred}")
print(f"Ehtimollik:{probs[pred_id]*100:.1f}")
img
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Bashorat:Airplane
# Ehtimollik:100.0
# PILImage mode=RGB size=612x324
